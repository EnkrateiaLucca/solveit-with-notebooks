# %% [markdown]
# # 🌱 Learning something new, the SolveIt way
#
# A realistic walk-through of meeting a **brand-new concept** and actually making it stick — using the toolkit as a thinking partner, not an answer machine.
#
# We'll learn **Python dictionaries** from scratch, but the *loop* works for anything:
#
# > **Meet it → Play with it → Anchor it → Solve with it → Check it → Keep it → Look back**
#
# Run the cells top to bottom. Swap `TOPIC` for whatever you're actually studying.

# %%
import sys; sys.path.append("..")
from solveit import *

TOPIC = "Python dictionaries"   # ← change me to study anything
# Out:
# ✅ **solveit loaded** · backend=`anthropic` · model=`claude-sonnet-4-5` · type `help_solveit()` for the cheat-sheet.

# %% [markdown]
# ## 1 · Meet it 💬
# Start a *dialogue*, not a one-shot prompt. The tutor remembers everything below, so follow-ups just work.

# %%
tutor.ask(f"I'm brand new to {TOPIC}. In a few sentences, what is it and why would I use one?")
# Out:
# A **dictionary** is like a real-world dictionary or a phone book - it stores pairs of information where you look things up by a **key** to get a **value**.
#
# **Quick example:**
# ```python
# student = {"name": "Alice", "age": 20, "grade": "A"}
# print(student["name"])  # Prints: Alice
# ```
#
# **Why use one?**
# - When you want to label your data (not just position like a list)
# - When you need to look things up quickly by name/ID
# - When related information belongs together
#
# Think: a list is like numbered boxes `[item1, item2, item3]`, but a dictionary is like labeled boxes `{"color": "red", "size": "large"}`.
#
# **Try this:** What kind of information about yourself would you want to store in a dictionary?

# %%
tutor.ask("Show me the tiniest possible example.")   # it knows what 'it' means
# Out:
# ```python
# age = {"Bob": 25}
# print(age["Bob"])  # Prints: 25
# ```
#
# That's it!
# - `"Bob"` is the **key** (what you look up)
# - `25` is the **value** (what you get back)
#
# **Want to try adding another person?**

# %% [markdown]
# ## 2 · Play with it 🧪
# An explanation **plus a live, interactive widget** in the cell — poke at it until it clicks.

# %%
explain_with_artifacts("how a Python dictionary looks up a value by its key")
# Out:
# # Dictionary Key Lookup
#
# A Python dictionary is like a filing cabinet where each drawer has a **label** (the key) and contains some **contents** (the value). When you look up a value by its key—like `my_dict["name"]`—Python uses the key as a direct address to find the value almost instantly, without checking every item one by one.
#
# Think of it like a phone's contacts list: you search for "Mom" (the key) and immediately get her phone number (the value), rather than scrolling through every contact.
# <div style='font-family:system-ui,sans-serif;margin-top:6px'><div style='display:flex;align-items:center;gap:8px;background:linear-gradient(135deg,#0ea5e9,#6366f1);color:white;padding:8px 14px;border-radius:10px 10px 0 0;font-weight:700;font-size:14px'>🧪 Explore: how a Python dictionary looks up a value by its <span style='font-weight:400;opacity:.85;font-size:12px'>· interactive — try it</span></div><iframe sandbox='allow-scripts allow-popups' srcdoc="<!doctype html>
# ...

# %% [markdown]
# ## 3 · Anchor it 🧠
# Turn the idea into a **visual mnemonic** — one weird, sticky picture you won't forget.

# %%
generate_visual_analogy("a Python dictionary maps unique keys to values, like a coat-check")
# Out:
# 🎨 *Drawing a visual analogy with `gemini` (`gemini-3-pro-image-preview`)…*
# Both GOOGLE_API_KEY and GEMINI_API_KEY are set. Using GOOGLE_API_KEY.
# <div style='font-family:system-ui,sans-serif;display:flex;gap:8px;align-items:center;background:linear-gradient(135deg,#f5c542,#e86b5a);color:#1a1a1a;padding:8px 14px;border-radius:10px;font-weight:700;font-size:14px;margin-top:6px'>🧠 Visual analogy · <span style='font-weight:500'>a Python dictionary maps unique keys to values, like a coat-check</span></div>
# ...

# %% [markdown]
# ## 4 · Solve with it 🧩
# Use the new tool on a tiny real problem — Pólya-style, you write each step.
# Run `.understand()`, then `.plan()`, then `.step()` (and `.step()` again), then `.review()`.

# %%
p = solve("Count how many times each word appears in a sentence")
p.understand()
# Out:
# ### 🧩 Problem
# Count how many times each word appears in a sentence
#
# *Use `.understand()`, `.plan()`, `.step()`, `.review()` to work through it.*
# #### 1 · Understand the problem
# # Stage 1 — UNDERSTAND
#
# Let me restate the problem:
#
# **In plain language:** We need to examine a sentence and count how many times each unique word occurs in it.
#
# **Input:** A sentence (text/string)
#
# **Output:** A count of each word and how many times it appears
#
# **Unknowns/Assumptions to clarify:**
#
# 1. **Case sensitivity:** Should "Hello" and "hello" be counted as the same word or different words?
#
# 2. **Punctuation:** If the sentence is "Hello, world! Hello there." — should "Hello," and "Hello" be treated as the same word, or does punctuation make them different?
#
# What are your assumptions for these two points?

# %%
p.plan()
# Out:
# #### 2 · Devise a plan
# # Stage 2 — PLAN
#
# Here's a step-by-step plan in plain English:
#
# 1. Take the input sentence as a string
# 2. Convert the sentence to lowercase (to handle case-insensitivity)
# 3. Remove punctuation from the sentence
# 4. Split the sentence into individual words
# 5. Create an empty dictionary to store word counts
# 6. Loop through each word in the list
# 7. For each word, check if it's already in the dictionary
# 8. If it exists, increase its count by 1
# 9. If it doesn't exist, add it to the dictionary with count 1
# 10. Display or return the dictionary with all word counts
#
# **Does this plan make sense to you? Can you see how each step could translate to 1-2 lines of code?**

# %%
p.step()   # the smallest next line — you type it yourself in the cell below
# Out:
# #### 3 · Carry it out (one tiny step)
# # Stage 3 — DO
#
# **Step 1:** Take the input sentence as a string
#
# ```python
# sentence = "Hello world! Hello there."
# print(sentence)
# ```
#
# **What to look for when you run it:**
# You should see the sentence printed exactly as you typed it.
#
# Try running this and let me know what you see!

# %%
# ✍️ Your turn: try the step here, run it, see what happens.
sentence = "the cat sat on the mat the cat"

# %% [markdown]
# ## 5 · Check it ✅
# A quick interactive quiz. Type answers in the boxes, hit submit, get color-coded feedback — and the `tutor` remembers it.

# %%
quiz(f"{TOPIC}: creating, looking up, and updating keys", n=3)

# %% [markdown]
# ## 6 · Keep it 🗂️
# Export what you just learned as **Anki cards** for spaced repetition (so it's still there next month).

# %%
anki(focus=f"the essentials of {TOPIC} I just learned", n=6)
# Out:
# <div style='font-family:system-ui,sans-serif'><div style='background:linear-gradient(135deg,#22c55e,#16a34a);color:white;padding:10px 16px;border-radius:10px;font-weight:700'>🗂️ 6 Anki cards saved</div><table style='border-collapse:collapse;margin-top:8px;font-size:13px'><tr><th style='text-align:left;padding:4px 10px'>Front</th><th style='text-align:left;padding:4px 10px'>Back</th></tr><tr><td style='padding:4px 10px;border-bottom:1px solid #eee'>What does this code print?&lt;br&gt;&lt;code&gt;student = {"name": "Alice", "age": 20}&lt;br&gt;print(student["name"])&lt;/code&gt;</td><td style='padding:4px 10px;border-bottom:1px solid #eee'>&lt;code&gt;Alice&lt;/code&gt;&lt;br&gt;&lt;br&gt;You use square brackets &lt;code&gt;[ ]&lt;/code&gt; with the key to look up its value in the dictionary.</td></tr><tr><td style='padding:4px 10px;border-bottom:1px solid #eee'>Fill in the blank to create a dictionary mapping "cat" to 4:&lt;br&gt;&lt;code&gt;pets = {___: ___}&lt;/code&gt;</td><td styl
# ...

# %% [markdown]
# ## 7 · Look back 🎓
# Close the loop: a warm recap of everything you covered and what to try next.

# %%
tutor.recap()
# Out:
# <div style='background:linear-gradient(135deg,#0ea5e9,#6366f1);color:white;padding:12px 18px;border-radius:12px;font-family:system-ui,sans-serif;font-size:17px;font-weight:700'>🎓 Session Recap</div>
# ## 📚 What we covered
# Python dictionaries — what they are, how they map keys to values, and how to look up and update information stored in them.
#
# ## 💡 Key takeaways
# - A dictionary stores **key-value pairs** (like "Bob": 25)
# - You look up values using square brackets: `age["Bob"]` returns `25`
# - Keys must be unique, like coat-check tickets — each one gets you one specific item
# - Dictionaries are perfect when you need to connect related pieces of information
# - You practiced a real problem: counting how many times each word appears in a sentence
#
# ## 🛠️ What you practiced
# - Creating dictionaries with curly braces `{}`
# - Looking up values by their keys
# - Working through a word-counting problem using Pólya's method
# ...

# %% [markdown]
# ---
# **That's the whole loop.** To study anything else: change `TOPIC` at the top, restart the kernel, and run it again. The human stays the agent — the AI proposes, *you* read, edit, and run. 🌱
