# %% [markdown]
# # 🧪 explain_with_artifacts — demo
#
# A quick tour of the new `explain_with_artifacts(...)` helper: it explains an idea **and** drops a live, interactive HTML artifact right into the cell.
#
# > Needs an API key: `export ANTHROPIC_API_KEY=...` (or `OPENAI_API_KEY=...`).

# %%
import sys; sys.path.append("..")
from solveit import *

# %% [markdown]
# ## Step through a loop
# ▶️ Run, then play with the artifact below the explanation.

# %%
explain_with_artifacts("for i in range(3): print(i)")

# %% [markdown]
# ## Visualize list indexing

# %%
explain_with_artifacts([10, 20, 30])

# %% [markdown]
# ## Your turn ✍️
# Swap in any concept, value, or snippet you want to explore.

# %%
explain_with_artifacts("f-strings in Python")

# %% [markdown]
# ---
# # 🧠 generate_visual_analogy — a picture you won't forget
#
# Turn a concept into a **minimal visual mnemonic**: the AI invents one striking metaphor, an image model draws it, and it renders inline with the caption.
#
# > Needs an image backend: **Gemini** (`pip install google-genai` + `GOOGLE_API_KEY`) or **OpenAI** (`gpt-image-2` + `OPENAI_API_KEY`). It auto-detects; force one with `configure_images(backend="gemini")`.

# %%
generate_visual_analogy("Python list indexing starts at 0")

# %%
generate_visual_analogy("a dictionary maps keys to values", aspect="16:9")
