# %% [markdown]
# # 🧪 explain_with_artifacts — demo
#
# A quick tour of the new `explain_with_artifacts(...)` helper: it explains an idea **and** drops a live, interactive HTML artifact right into the cell.
#
# > Needs an API key: `export ANTHROPIC_API_KEY=...` (or `OPENAI_API_KEY=...`).

# %%
import sys; sys.path.append("..")
from solveit import *
# Out:
# ✅ **solveit loaded** · backend=`anthropic` · model=`claude-sonnet-4-5` · type `help_solveit()` for the cheat-sheet.

# %% [markdown]
# ## Step through a loop
# ▶️ Run, then play with the artifact below the explanation.

# %%
explain_with_artifacts("for i in range(3): print(i)")
# Out:
# # Explanation
#
# A `for` loop in Python repeats a block of code multiple times. Here, `range(3)` creates a sequence of numbers: 0, 1, 2 (it starts at 0 and stops *before* 3). The variable `i` takes on each of these values in turn, and `print(i)` displays it.
#
# **Analogy:** It's like a ticket dispenser that hands you numbered tickets one at a time—first ticket #0, then #1, then #2—and you announce each number as you receive it.
# <div style='font-family:system-ui,sans-serif;margin-top:6px'><div style='display:flex;align-items:center;gap:8px;background:linear-gradient(135deg,#0ea5e9,#6366f1);color:white;padding:8px 14px;border-radius:10px 10px 0 0;font-weight:700;font-size:14px'>🧪 Explore: for i in range(3): print(i)<span style='font-weight:400;opacity:.85;font-size:12px'>· interactive — try it</span></div><iframe sandbox='allow-scripts allow-popups' srcdoc="<!doctype html>
# <html lang=&quot;en&quot;>
# <head>
# <meta charset=&quot;UTF-8&quot;>
# <meta name=&quot;viewport&quot; content=&quot;width=device-width, initial-scale=1.0&quot;>
# <title>Python for Loop Explorer</title>
# <style>
#   body {
#     font-family: system-ui, -apple-system, sans-serif;
#     max-width: 600px;
#     margin: 40px auto;
#     padding: 20px;
#     background: linear-gradient(135deg, #667eea 0%, #764ba2 100%);
#     min-height: 100vh;
#   }
#   .container {
#     background: white;
#     border-radius: 16px;
#     padding: 32px;
#     box-shadow: 0 8px 32px rgba(0,0,0,0.1);
#   }
#   h1 {
#     margin: 0 0 8px 0;
#     color: #2d3748;
#     font-size: 24px;
#   }
#   .code-box {
#     background: #f7fafc;
#     border: 2px solid #e2e8f0;
#     border-radius: 12px;
#     padding: 16px;
#     font-family: 'Courier New', monospace;
#     font-size: 16px;
#     margin: 20px 0;
#     color: #2d3748;
#   }
#   .highlight {
#     background: #fef3c7;
#     padding: 2px 4px;
#     border-radius: 4px;
#     font-weight: bold;
#   }
#   .control-panel {
#     background: #edf2f7;
#     border-radius: 12px;
#     padding: 20px;
#     margin: 20px 0;
#   }
#   label {
#     display: block;
#     margin-bottom: 8px;
#     font-weight: 600;
#     color: #4a5568;
#   }
#   input[type=&quot;range&quot;] {
#     width: 100%;
#     height: 8px;
#     border-radius: 4px;
#     background: #cbd5e0;
#     outline: none;
#     margin: 8px 0;
#   }
#   input[type=&quot;range&quot;]::-webkit-slider-thumb {
#     appearance: none;
#     width: 24px;
#     height: 24px;
#     border-radius: 50%;
#     background: #667eea;
#     cursor: pointer;
#   }
#   input[type=&quot;range&quot;]::-moz-range-thumb {
#     width: 24px;
#     height: 24px;
#     border-radius: 50%;
#     background: #667eea;
#     cursor: pointer;
#     border: none;
#   }
#   .value-display {
#     font-size: 18px;
#     font-weight: bold;
#     color: #667eea;
#     margin-top: 8px;
#   }
#   button {
#     background: #667eea;
#     color: white;
#     border: none;
#     padding: 12px 24px;
#     border-radius: 8px;
#     font-size: 16px;
#     font-weight: 600;
#     cursor: pointer;
#     margin: 8px 4px 0 0;
#     transition: background 0.2s;
#   }
#   button:hover {
#     background: #5568d3;
#   }
#   button:active {
#     transform: scale(0.98);
#   }
#   .output-box {
#     background: #1a202c;
#     color: #48bb78;
#     border-radius: 12px;
#     padding: 16px;
#     font-family: 'Courier New', monospace;
#     font-size: 16px;
#     min-height: 80px;
#     margin-top: 16px;
#   }
#   .output-line {
#     margin: 4px 0;
#     animation: fadeIn 0.3s;
#   }
#   @keyframes fadeIn {
#     from { opacity: 0; transform: translateX(-10px); }
#     to { opacity: 1; transform: translateX(0); }
#   }
#   .ticket-container {
#     display: flex;
#     gap: 12px;
#     margin: 16px 0;
#     flex-wrap: wrap;
#   }
#   .ticket {
#     background: white;
#     border: 3px solid #cbd5e0;
#     border-radius: 8px;
#     padding: 16px 20px;
#     font-size: 24px;
#     font-weight: bold;
#     color: #4a5568;
#     min-width: 60px;
#     text-align: center;
#     transition: all 0.3s;
#   }
#   .ticket.active {
#     border-color: #667eea;
#     background: #667eea;
#     color: white;
#     transform: scale(1.1);
#   }
#   .ticket.done {
#     border-color: #48bb78;
#     background: #f0fff4;
#     color: #48bb78;
#   }
# </style>
# </head>
# <body>
# <div class=&quot;container&quot;>
#   <h1>🔁 Python for Loop</h1>
#   <p style=&quot;color: #718096; margin-top: 4px;&quot;>Watch how the loop visits each number</p>
#
#   <div class=&quot;code-box&quot;>
#     <div>for i in range(<span class=&quot;highlight&quot; id=&quot;rangeValue&quot;>3</span>):</div>
#     <div>&amp;nbsp;&amp;nbsp;&amp;nbsp;&amp;nbsp;print(i)</div>
#   </div>
#
#   <div class=&quot;control-panel&quot;>
#     <label>Adjust range(n) — how many numbers?</label>
#     <input type=&quot;range&quot; id=&quot;rangeSlider&quot; min=&quot;1&quot; max=&quot;8&quot; value=&quot;3&quot;>
#     <div class=&quot;value-display&quot;>range(<span id=&quot;currentValue&quot;>3</span>) → produces: 0, 1, 2</div>
#   </div>
#
#   <div style=&quot;margin: 20px 0;&quot;>
#     <button id=&quot;runBtn&quot;>▶ Run Loop</button>
#     <button id=&quot;stepBtn&quot;>Step Through</button>
#     <button id=&quot;resetBtn&quot;>Reset</button>
#   </div>
#
#   <div id=&quot;ticketContainer&quot; class=&quot;ticket-container&quot;></div>
#
#   <div class=&quot;output-box&quot; id=&quot;output&quot;>
#     <div style=&quot;color: #718096;&quot;>Output will appear here...</div>
#   </div>
# </div>
#
# <script>
#   const slider = document.getElementById('rangeSlider');
#   const rangeValue = document.getElementById('rangeValue');
#   const currentValue = document.getElementById('currentValue');
#   const runBtn = document.getElementById('runBtn');
#   const stepBtn = document.getElementById('stepBtn');
#   const resetBtn = document.getElementById('resetBtn');
#   const output = document.getElementById('output');
#   const ticketContainer = document.getElementById('ticketContainer');
#
#   let currentStep = -1;
#   let maxSteps = 3;
#   let isRunning = false;
#
#   function updateRange() {
#     const val = slider.value;
#     maxSteps = parseInt(val);
#     rangeValue.textContent = val;
#     currentValue.textContent = val;
#
#     const nums = Array.from({length: maxSteps}, (_, i) => i).join(', ');
#     currentValue.parentElement.innerHTML = `range(<span id=&quot;currentValue&quot;>${val}</span>) → produces: ${nums}`;
#
#     renderTickets();
#     resetLoop();
#   }
#
#   function renderTickets() {
#     ticketContainer.innerHTML = '';
#     for (let i = 0; i < maxSteps; i++) {
#       const ticket = document.createElement('div');
#       ticket.className = 'ticket';
#       ticket.textContent = i;
#       ticket.id = `ticket-${i}`;
#       ticketContainer.appendChild(ticket);
#     }
#   }
#
#   function resetLoop() {
#     currentStep = -1;
#     isRunning = false;
#     output.innerHTML = '<div style=&quot;color: #718096;&quot;>Output will appear here...</div>';
#     document.querySelectorAll('.ticket').forEach(t => {
#       t.classList.remove('active', 'done');
#     });
#     stepBtn.textContent = 'Step Through';
#   }
#
#   function stepLoop() {
#     if (currentStep >= maxSteps - 1) {
#       resetLoop();
#       return;
#     }
#
#     if (currentStep >= 0) {
#       document.getElementById(`ticket-${currentStep}`).classList.remove('active');
#       document.getElementById(`ticket-${currentStep}`).classList.add('done');
#     }
#
#     currentStep++;
#
#     if (currentStep === 0) {
#       output.innerHTML = '';
#     }
#
#     const ticket = document.getElementById(`ticket-${currentStep}`);
#     ticket.classList.add('active');
#
#     const line = document.createElement('div');
#     line.className = 'output-line';
#     line.textContent = currentStep;
#     output.appendChild(line);
#
#     if (currentStep === maxSteps - 1) {
#       stepBtn.textContent = '↺ Reset &amp; Step Again';
#     }
#   }
#
#   async function runLoop() {
#     if (isRunning) return;
#     isRunning = true;
#     resetLoop();
#
#     for (let i = 0; i < maxSteps; i++) {
#       await new Promise(resolve => setTimeout(resolve, 600));
#       stepLoop();
#     }
#
#     isRunning = false;
#   }
#
#   slider.addEventListener('input', updateRange);
#   runBtn.addEventListener('click', runLoop);
#   stepBtn.addEventListener('click', stepLoop);
#   resetBtn.addEventListener('click', resetLoop);
#
#   // Initialize
#   updateRange();
# </script>
# </body>
# </html>" style='width:100%;height:420px;border:1px solid #e5e7eb;border-top:0;border-radius:0 0 10px 10px;background:white'></iframe></div>
# "# Explanation\n\nA `for` loop in Python repeats a block of code multiple times. Here, `range(3)` creates a sequence of numbers: 0, 1, 2 (it starts at 0 and stops *before* 3). The variable `i` takes on each of these values in turn, and `print(i)` displays it.\n\n**Analogy:** It's like a ticket dispenser that hands you numbered tickets one at a time—first ticket #0, then #1, then #2—and you announce each number as you receive it."

# %% [markdown]
# ## Visualize list indexing

# %%
explain_with_artifacts([10, 20, 30])
# Out:
# ## What is `[10, 20, 30]`?
#
# This is a **list** in Python—think of it like a row of numbered boxes where you can store items in order. Each box has a position (called an **index**) starting from 0. So `10` is at position 0, `20` is at position 1, and `30` is at position 2.
#
# **Analogy:** It's like a playlist where songs are played in order, and you can jump to any song by its track number (starting from track 0).
# <div style='font-family:system-ui,sans-serif;margin-top:6px'><div style='display:flex;align-items:center;gap:8px;background:linear-gradient(135deg,#0ea5e9,#6366f1);color:white;padding:8px 14px;border-radius:10px 10px 0 0;font-weight:700;font-size:14px'>🧪 Explore: [10, 20, 30]<span style='font-weight:400;opacity:.85;font-size:12px'>· interactive — try it</span></div><iframe sandbox='allow-scripts allow-popups' srcdoc="<!doctype html>
# <html lang=&quot;en&quot;>
# <head>
# <meta charset=&quot;UTF-8&quot;>
# <meta name=&quot;viewport&quot; content=&quot;width=device-width, initial-scale=1.0&quot;>
# <title>Python List Explorer</title>
# <style>
#   body {
#     font-family: system-ui, -apple-system, sans-serif;
#     background: linear-gradient(135deg, #667eea 0%, #764ba2 100%);
#     min-height: 100vh;
#     display: flex;
#     align-items: center;
#     justify-content: center;
#     margin: 0;
#     padding: 20px;
#     box-sizing: border-box;
#   }
#   .container {
#     background: white;
#     border-radius: 20px;
#     padding: 40px;
#     box-shadow: 0 20px 60px rgba(0,0,0,0.3);
#     max-width: 600px;
#     width: 100%;
#   }
#   h1 {
#     margin: 0 0 10px 0;
#     color: #333;
#     font-size: 28px;
#   }
#   .subtitle {
#     color: #666;
#     margin: 0 0 30px 0;
#     font-size: 16px;
#   }
#   .list-display {
#     display: flex;
#     gap: 15px;
#     justify-content: center;
#     margin: 30px 0;
#   }
#   .list-item {
#     background: #f0f0f0;
#     border: 3px solid #ddd;
#     border-radius: 12px;
#     padding: 20px;
#     min-width: 80px;
#     text-align: center;
#     transition: all 0.3s ease;
#   }
#   .list-item.active {
#     background: #667eea;
#     border-color: #667eea;
#     color: white;
#     transform: scale(1.1);
#     box-shadow: 0 5px 15px rgba(102, 126, 234, 0.4);
#   }
#   .index {
#     font-size: 12px;
#     font-weight: bold;
#     color: #999;
#     margin-bottom: 5px;
#   }
#   .list-item.active .index {
#     color: #e0e7ff;
#   }
#   .value {
#     font-size: 24px;
#     font-weight: bold;
#     color: #333;
#   }
#   .list-item.active .value {
#     color: white;
#   }
#   .controls {
#     background: #f8f9fa;
#     padding: 25px;
#     border-radius: 12px;
#     margin: 20px 0;
#   }
#   .control-group {
#     margin-bottom: 20px;
#   }
#   .control-group:last-child {
#     margin-bottom: 0;
#   }
#   label {
#     display: block;
#     font-weight: 600;
#     margin-bottom: 10px;
#     color: #333;
#     font-size: 14px;
#   }
#   .button-group {
#     display: flex;
#     gap: 10px;
#     flex-wrap: wrap;
#   }
#   button {
#     background: #667eea;
#     color: white;
#     border: none;
#     padding: 12px 24px;
#     border-radius: 8px;
#     font-size: 14px;
#     font-weight: 600;
#     cursor: pointer;
#     transition: all 0.2s ease;
#     flex: 1;
#     min-width: 100px;
#   }
#   button:hover {
#     background: #5568d3;
#     transform: translateY(-2px);
#     box-shadow: 0 5px 15px rgba(102, 126, 234, 0.3);
#   }
#   button:active {
#     transform: translateY(0);
#   }
#   .output {
#     background: #2d3748;
#     color: #e2e8f0;
#     padding: 20px;
#     border-radius: 8px;
#     font-family: 'Courier New', monospace;
#     font-size: 14px;
#     line-height: 1.6;
#     min-height: 60px;
#   }
#   .code {
#     color: #a78bfa;
#     font-weight: bold;
#   }
#   .result {
#     color: #34d399;
#   }
# </style>
# </head>
# <body>
# <div class=&quot;container&quot;>
#   <h1>Python List: [10, 20, 30]</h1>
#   <p class=&quot;subtitle&quot;>Click buttons to see how lists work in Python!</p>
#
#   <div class=&quot;list-display&quot;>
#     <div class=&quot;list-item&quot; id=&quot;item-0&quot;>
#       <div class=&quot;index&quot;>index: 0</div>
#       <div class=&quot;value&quot;>10</div>
#     </div>
#     <div class=&quot;list-item&quot; id=&quot;item-1&quot;>
#       <div class=&quot;index&quot;>index: 1</div>
#       <div class=&quot;value&quot;>20</div>
#     </div>
#     <div class=&quot;list-item&quot; id=&quot;item-2&quot;>
#       <div class=&quot;index&quot;>index: 2</div>
#       <div class=&quot;value&quot;>30</div>
#     </div>
#   </div>
#
#   <div class=&quot;controls&quot;>
#     <div class=&quot;control-group&quot;>
#       <label>Access by Index:</label>
#       <div class=&quot;button-group&quot;>
#         <button onclick=&quot;accessIndex(0)&quot;>my_list[0]</button>
#         <button onclick=&quot;accessIndex(1)&quot;>my_list[1]</button>
#         <button onclick=&quot;accessIndex(2)&quot;>my_list[2]</button>
#       </div>
#     </div>
#
#     <div class=&quot;control-group&quot;>
#       <label>Try These:</label>
#       <div class=&quot;button-group&quot;>
#         <button onclick=&quot;getLength()&quot;>len(my_list)</button>
#         <button onclick=&quot;getFirst()&quot;>my_list[0]</button>
#         <button onclick=&quot;getLast()&quot;>my_list[-1]</button>
#       </div>
#     </div>
#   </div>
#
#   <div class=&quot;output&quot; id=&quot;output&quot;>
#     Click a button above to interact with the list!
#   </div>
# </div>
#
# <script>
#   const myList = [10, 20, 30];
#
#   function clearHighlight() {
#     document.querySelectorAll('.list-item').forEach(item => {
#       item.classList.remove('active');
#     });
#   }
#
#   function highlightItem(index) {
#     clearHighlight();
#     const item = document.getElementById(`item-${index}`);
#     if (item) {
#       item.classList.add('active');
#     }
#   }
#
#   function showOutput(code, result, highlightIdx = null) {
#     const output = document.getElementById('output');
#     output.innerHTML = `<span class=&quot;code&quot;>${code}</span><br>→ <span class=&quot;result&quot;>${result}</span>`;
#
#     if (highlightIdx !== null) {
#       highlightItem(highlightIdx);
#     } else {
#       clearHighlight();
#     }
#   }
#
#   function accessIndex(index) {
#     const value = myList[index];
#     showOutput(`my_list[${index}]`, value, index);
#   }
#
#   function getLength() {
#     const length = myList.length;
#     showOutput(`len(my_list)`, length);
#   }
#
#   function getFirst() {
#     const value = myList[0];
#     showOutput(`my_list[0]`, `${value} (first item)`, 0);
#   }
#
#   function getLast() {
#     const value = myList[myList.length - 1];
#     const lastIndex = myList.length - 1;
#     showOutput(`my_list[-1]`, `${value} (last item, same as my_list[${lastIndex}])`, lastIndex);
#   }
# </script>
# </body>
# </html>" style='width:100%;height:420px;border:1px solid #e5e7eb;border-top:0;border-radius:0 0 10px 10px;background:white'></iframe></div>
# "## What is `[10, 20, 30]`?\n\nThis is a **list** in Python—think of it like a row of numbered boxes where you can store items in order. Each box has a position (called an **index**) starting from 0. So `10` is at position 0, `20` is at position 1, and `30` is at position 2.\n\n**Analogy:** It's like a playlist where songs are played in order, and you can jump to any song by its track number (starting from track 0)."

# %% [markdown]
# ## Your turn ✍️
# Swap in any concept, value, or snippet you want to explore.

# %%
explain_with_artifacts("f-strings in Python")
# Out:
# # Beginner Explanation
#
# An **f-string** is a special type of string in Python that lets you insert variables directly into your text by putting an `f` before the quotes and wrapping variable names in curly braces `{}`. It's like a template with blanks you can fill in!
#
# Think of it like a form letter: "Dear `{name}`, you won {prize}!" — the f-string fills in the blanks with actual values when Python runs your code.
#
# ---
# <div style='font-family:system-ui,sans-serif;margin-top:6px'><div style='display:flex;align-items:center;gap:8px;background:linear-gradient(135deg,#0ea5e9,#6366f1);color:white;padding:8px 14px;border-radius:10px 10px 0 0;font-weight:700;font-size:14px'>🧪 Explore: f-strings in Python<span style='font-weight:400;opacity:.85;font-size:12px'>· interactive — try it</span></div><iframe sandbox='allow-scripts allow-popups' srcdoc="<!doctype html>
# <html lang=&quot;en&quot;>
# <head>
#     <meta charset=&quot;UTF-8&quot;>
#     <meta name=&quot;viewport&quot; content=&quot;width=device-width, initial-scale=1.0&quot;>
#     <title>F-Strings Playground</title>
#     <style>
#         body {
#             font-family: system-ui, -apple-system, sans-serif;
#             max-width: 700px;
#             margin: 40px auto;
#             padding: 20px;
#             background: linear-gradient(135deg, #667eea 0%, #764ba2 100%);
#             color: #333;
#         }
#         .container {
#             background: white;
#             border-radius: 16px;
#             padding: 30px;
#             box-shadow: 0 8px 32px rgba(0,0,0,0.2);
#         }
#         h1 {
#             margin-top: 0;
#             color: #667eea;
#             font-size: 24px;
#         }
#         .input-group {
#             margin: 20px 0;
#             padding: 15px;
#             background: #f8f9ff;
#             border-radius: 12px;
#             border: 2px solid #e0e7ff;
#         }
#         label {
#             display: block;
#             font-weight: 600;
#             margin-bottom: 8px;
#             color: #555;
#         }
#         input {
#             width: 100%;
#             padding: 10px;
#             border: 2px solid #ddd;
#             border-radius: 8px;
#             font-size: 16px;
#             box-sizing: border-box;
#             transition: border-color 0.3s;
#         }
#         input:focus {
#             outline: none;
#             border-color: #667eea;
#         }
#         .code-box {
#             background: #2d3748;
#             color: #e2e8f0;
#             padding: 16px;
#             border-radius: 10px;
#             font-family: 'Courier New', monospace;
#             font-size: 14px;
#             margin: 15px 0;
#             line-height: 1.6;
#         }
#         .output {
#             background: #fef3c7;
#             border-left: 4px solid #f59e0b;
#             padding: 16px;
#             border-radius: 8px;
#             margin: 15px 0;
#             font-size: 16px;
#         }
#         .highlight {
#             color: #fbbf24;
#             font-weight: bold;
#         }
#         .note {
#             background: #e0f2fe;
#             padding: 12px;
#             border-radius: 8px;
#             margin-top: 20px;
#             font-size: 14px;
#             border-left: 4px solid #0ea5e9;
#         }
#     </style>
# </head>
# <body>
#     <div class=&quot;container&quot;>
#         <h1>🐍 F-Strings Playground</h1>
#         <p>Type in the boxes below and watch the f-string fill in the blanks instantly!</p>
#
#         <div class=&quot;input-group&quot;>
#             <label>Your Name:</label>
#             <input type=&quot;text&quot; id=&quot;name&quot; value=&quot;Alice&quot; placeholder=&quot;Enter a name&quot;>
#         </div>
#
#         <div class=&quot;input-group&quot;>
#             <label>Your Age:</label>
#             <input type=&quot;number&quot; id=&quot;age&quot; value=&quot;25&quot; placeholder=&quot;Enter age&quot;>
#         </div>
#
#         <div class=&quot;input-group&quot;>
#             <label>Favorite Color:</label>
#             <input type=&quot;text&quot; id=&quot;color&quot; value=&quot;blue&quot; placeholder=&quot;Enter a color&quot;>
#         </div>
#
#         <div class=&quot;code-box&quot;>
#             <div style=&quot;color: #a0aec0;&quot;># Python code:</div>
#             <div>name = <span class=&quot;highlight&quot;>&quot;<span id=&quot;name-display&quot;>Alice</span>&quot;</span></div>
#             <div>age = <span class=&quot;highlight&quot;><span id=&quot;age-display&quot;>25</span></span></div>
#             <div>color = <span class=&quot;highlight&quot;>&quot;<span id=&quot;color-display&quot;>blue</span>&quot;</span></div>
#             <div style=&quot;margin-top: 10px;&quot;>message = <span class=&quot;highlight&quot;>f</span>&quot;Hello, {name}! You are {age} and love {color}.&quot;</div>
#         </div>
#
#         <div class=&quot;output&quot;>
#             <strong>Output:</strong><br>
#             <span id=&quot;output&quot;>Hello, Alice! You are 25 and love blue.</span>
#         </div>
#
#         <div class=&quot;note&quot;>
#             💡 <strong>Notice:</strong> The <code>f</code> before the quote makes it an f-string. The <code>{curly braces}</code> insert variable values directly into the text!
#         </div>
#     </div>
#
#     <script>
#         const nameInput = document.getElementById('name');
#         const ageInput = document.getElementById('age');
#         const colorInput = document.getElementById('color');
#
#         const nameDisplay = document.getElementById('name-display');
#         const ageDisplay = document.getElementById('age-display');
#         const colorDisplay = document.getElementById('color-display');
#         const output = document.getElementById('output');
#
#         function updateOutput() {
#             const name = nameInput.value || 'Someone';
#             const age = ageInput.value || '0';
#             const color = colorInput.value || 'rainbow';
#
#             nameDisplay.textContent = name;
#             ageDisplay.textContent = age;
#             colorDisplay.textContent = color;
#
#             output.textContent = `Hello, ${name}! You are ${age} and love ${color}.`;
#         }
#
#         nameInput.addEventListener('input', updateOutput);
#         ageInput.addEventListener('input', updateOutput);
#         colorInput.addEventListener('input', updateOutput);
#
#         updateOutput();
#     </script>
# </body>
# </html>" style='width:100%;height:420px;border:1px solid #e5e7eb;border-top:0;border-radius:0 0 10px 10px;background:white'></iframe></div>
# '# Beginner Explanation\n\nAn **f-string** is a special type of string in Python that lets you insert variables directly into your text by putting an `f` before the quotes and wrapping variable names in curly braces `{}`. It\'s like a template with blanks you can fill in!\n\nThink of it like a form letter: "Dear `{name}`, you won {prize}!" — the f-string fills in the blanks with actual values when Python runs your code.\n\n---'
